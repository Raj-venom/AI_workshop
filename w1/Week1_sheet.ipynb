# %% [markdown]
# # Introduction to Python Imaging Library(PIL)

# %%
from PIL import Image

# %%
image_colored = Image.open('/content/drive/MyDrive/Level 6/AI & ML/w1/girl.png')

# %%
print("Format:", image_colored.format)
print("Mode:", image_colored.mode)
print("Size:", image_colored.size)
# Out:
# Format: PNG
# Mode: RGB
# Size: (366, 357)

# %%
# display image using matplotlib
import matplotlib.pyplot as plt
plt.imshow(image_colored)
plt.show()

# %% [markdown]
# Display only the top left corner of 100x100 pixels.
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.

# %%
# display only the top left corner of 100 x 100 pixels  usingnumpy
import numpy as np
image_array_colored = np.array(image_colored)
print("Before croping")
print(image_array_colored.shape)

# extracting 100 X 100 row and col
image_array_colored_cropped = image_array_colored[:100, :100]
print("\nAfte croping:")
print(image_array_colored_cropped.shape)

plt.imshow(image_array_colored_cropped)
plt.show()
# Out:
# Before croping
# (357, 366, 3)
#
# Afte croping:
# (100, 100, 3)

# %% [markdown]
# 3. Show the three color channels (R, G, B).
# • Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
red_channel = image_array_colored.copy()
red_channel[:, :, 1] = 0
red_channel[:, :, 2] = 0
plt.imshow(red_channel)
plt.title('Red Channel')
plt.show()

# %%
green_channel = image_array_colored.copy()
green_channel[:, :, 0] = 0 # height, widht , and channel value get zero
green_channel[:, :, 2] = 0
plt.imshow(green_channel)
plt.title('Green Channel')
plt.show()

# %%
blue_channel = image_array_colored.copy()
blue_channel[:, :, 0] = 0
blue_channel[:, :, 1] = 0
plt.imshow(blue_channel)
plt.title('Blue Channel')
plt.show()
#

# %%
plt.subplot(1, 3, 1)
plt.imshow(red_channel, cmap='Reds')
plt.title('Red Channel')

plt.subplot(1, 3, 2)
plt.imshow(green_channel, cmap='Greens')
plt.title('Green Channel')

plt.subplot(1, 3, 3)
plt.imshow(blue_channel, cmap='Blues')
plt.title('Blue Channel')

plt.show()

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image.

# %%
# Modify the top-left 100x100 pixels to a value of 210
top_left_100x100 = image_array_colored.copy()
top_left_100x100[:100, :100] = 210

# display
plt.imshow(top_left_100x100)
plt.show()

# %% [markdown]
# ## Exercise - 2:

# %% [markdown]
# 1. Load and display a grayscale image.
#
# - Load a grayscale image using the Pillow library.
#
#
#
# - Display the grayscale image using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

image_camera = Image.open('/content/drive/MyDrive/Level 6/AI & ML/w1/Copy of cameraman.png').convert("L")
plt.imshow(image_camera, cmap='gray')
plt.title('Grayscale Image')
plt.show()

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
# - Extract a 150 pixel section from the center of the image using NumPy array slicing.
# - Display this cropped image using matplotlib.

# %%
image_camera_array = np.array(image_camera)
image_camera_array.shape
# Out:
# (512, 512)

# %%
# Extract and display the middle section of the image (150 pixels).
# Extract a 150 pixel section from the center of the image using NumPy array slicing.
# Display this cropped image using matplotlib
middle_section = image_camera_array[image_camera_array.shape[0] // 2 - 75:image_camera_array.shape[0] // 2 + 75,
                                    image_camera_array.shape[1] // 2 - 75:image_camera_array.shape[1] // 2 + 75]
plt.imshow(middle_section, cmap='gray')
plt.title('Middle 150x150 pixels')
plt.show()

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
# - Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).
# - Display the resulting binary image.

# %%
threashold_value = 100
binary_image_array = np.where(image_camera_array < threashold_value, 0, 255)
plt.imshow(binary_image_array, cmap='gray')
plt.title('Binary Image')
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
# - Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
# - Display the rotated image using matplotlib.

# %%
# roate image by 90 degree clockwise using pillow roate

rotated_image = image_camera.rotate(-90)
plt.imshow(rotated_image, cmap='gray')
plt.title('Rotated Image')
plt.show()

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
# - Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
# - Display the converted RGB image using matplotlib.

# %%
image_camera_rgb = image_camera.convert("RGB")

image_camera_rgb_array = np.array(image_camera_rgb)
print(image_camera_rgb_array.shape)

plt.imshow(image_camera_rgb_array)
plt.title('RGB Image')
plt.show()
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Image Compression and Decompression using PCA.

# %% [markdown]
# 1. Load and Prepare Data:
# - Fetch an image of you choice.{If colour convert to grayscale}
# - Center the dataset - Standaridze the Data.
# - Calculate the covaraince matrix of the Standaridze data

# %%
image_colored = Image.open('/content/drive/MyDrive/Level 6/AI & ML/w1/girl.png')

image_grayed = image_colored.convert("L")
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=366x357>

# %%
gray_img_array = np.array(image_grayed)
print("Grayed image shape",gray_img_array.shape)

# standardize the ata (centering)
mean_value = np.mean(gray_img_array)
print("Mean value:",mean_value)

standardized_data = gray_img_array - mean_value

# Calculate the covaraince matrix of the Standaridze data.
cov_matrix = np.cov(standardized_data , rowvar=False)
print("Covariance matrix:\n",cov_matrix)
# Out:
# Grayed image shape (357, 366)
# Mean value: 123.22885000994934
# Covariance matrix:
#  [[1482.61322507 1444.75413087 1404.48079344 ... -477.00334403
#   -463.70533944 -416.64351808]
#  [1444.75413087 1430.68506279 1399.06857237 ... -546.38764045
#   -531.51999339 -485.93803701]
#  [1404.48079344 1399.06857237 1391.50350927 ... -581.36182451
#   -565.21914833 -521.85069871]
#  ...
#  [-477.00334403 -546.38764045 -581.36182451 ... 3069.65783842
#   3039.86677368 3007.1540931 ]
#  [-463.70533944 -531.51999339 -565.21914833 ... 3039.86677368
#   3036.6898782  3021.25177037]
#  [-416.64351808 -485.93803701 -521.85069871 ... 3007.1540931
#   3021.25177037 3034.25092059]]

# %% [markdown]
# 2. Eigen Decomposition and Identifying Principal Components:
# - Compute Eigen Values and Eigen Vectors.
# - Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
# the highest eigenvalues.
# - Identify the Principal Components with the help of cumulative Sum plot

# %%
# Compute Eigenvalues and Eigenvectors
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

# Sort Eigenvalues and corresponding Eigenvectors in descending order
sorted_indices = np.argsort(eigenvalues)[::-1]  # Descending order
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# Compute Cumulative Sum of Eigenvalues for Explained Variance
explained_variance = np.cumsum(eigenvalues) / np.sum(eigenvalues)

# Plot the explained variance
plt.figure(figsize=(6, 4))
plt.plot(explained_variance, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance')
plt.title('Explained Variance vs. Number of Components')
plt.grid()
plt.show()

# %% [markdown]
# 3. Reconstruction and Experiment:
# - Reconstruction: Transform the original data by multiplying it with the selected eigenvectors(PCs) to obtain a lower-dimensional representation.
# - Experiments: Pick Four different combination of principal components with various explained variance value and compare the result.
# - Display the Results and Evaluate.

# %%
# Step 3: Choose k Principal Components and Reconstruct
def reconstruct_image(k):
    """ Reconstructs image using top k principal components """
    top_eigenvectors = eigenvectors[:, :k]  # Select top k eigenvectors
    reduced_data = np.dot(standardized_data, top_eigenvectors)  # Project onto new space
    reconstructed_data = np.dot(reduced_data, top_eigenvectors.T) + mean_value  # Reconstruct

    return np.clip(reconstructed_data, 0, 255)  # Clip values to valid image range

# Experiment with different k values
k_values = [10, 20, 50, 100, 150]
fig, axes = plt.subplots(1, len(k_values), figsize=(12, 4))

for i, k in enumerate(k_values):
    reconstructed_image = reconstruct_image(k)
    axes[i].imshow(reconstructed_image, cmap='gray')
    axes[i].set_title(f'k = {k}')
    axes[i].axis('off')

plt.show()
